# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
num_dat = 200
dat = np.random.randn(num_dat * 2).reshape(2, num_dat)

# %%
plt.scatter(dat[0,:], dat[1,:])

# %%
A = np.array([1,0.9,0.9,1]).reshape((2,2))
print(A)
# Out:
# [[1.  0.9]
#  [0.9 1. ]]

# %%
dat2 = np.dot(A, dat)

# %%
print(dat.shape)
print(dat2.shape)
# Out:
# (2, 200)
# (2, 200)

# %%
print(dat)
print(dat2)
# Out:
# [[ 1.81008695e+00 -3.28591612e-01 -1.74893817e+00 -1.97635991e-01
#    2.24899689e-02 -2.72458801e+00 -2.13356490e-02  3.37199395e-01
#    9.47808730e-01 -7.37079290e-02 -3.99947576e-01  4.53501933e-01
#    3.14922858e-01  7.55045768e-01 -4.14351323e-02 -8.69995504e-01
#   -1.12146777e+00 -4.22478370e-01  6.97834554e-01  5.62519232e-01
#    1.01033659e+00  1.39792979e+00 -5.71048480e-01  2.67712290e-01
#    5.00895556e-01  1.27352819e+00 -2.87275636e-01  2.91453454e-01
#    1.21988333e+00 -6.56120676e-01 -4.22623785e-01 -7.68281440e-01
#   -2.60545195e-01  2.79227129e-01  6.58469938e-01 -2.16770325e+00
#    1.56333058e+00 -5.93917331e-01 -9.61303264e-01 -1.34834674e-01
#   -1.26969095e+00  1.77959235e+00  3.84267435e-01  5.18701842e-02
#    2.73490490e-01 -9.74261956e-02  7.67263800e-01  1.30311522e-01
#    3.95370787e-03 -1.58794012e-02 -8.02140326e-01 -2.47271322e+00
#    8.73084354e-01  7.06034889e-01 -6.91739434e-02  2.34498092e-01
# ...

# %%
print(dat[0,:])
print(dat[1,:])
print(dat2[0,:])
print(dat2[1,:])
# Out:
# [ 1.81008695e+00 -3.28591612e-01 -1.74893817e+00 -1.97635991e-01
#   2.24899689e-02 -2.72458801e+00 -2.13356490e-02  3.37199395e-01
#   9.47808730e-01 -7.37079290e-02 -3.99947576e-01  4.53501933e-01
#   3.14922858e-01  7.55045768e-01 -4.14351323e-02 -8.69995504e-01
#  -1.12146777e+00 -4.22478370e-01  6.97834554e-01  5.62519232e-01
#   1.01033659e+00  1.39792979e+00 -5.71048480e-01  2.67712290e-01
#   5.00895556e-01  1.27352819e+00 -2.87275636e-01  2.91453454e-01
#   1.21988333e+00 -6.56120676e-01 -4.22623785e-01 -7.68281440e-01
#  -2.60545195e-01  2.79227129e-01  6.58469938e-01 -2.16770325e+00
#   1.56333058e+00 -5.93917331e-01 -9.61303264e-01 -1.34834674e-01
#  -1.26969095e+00  1.77959235e+00  3.84267435e-01  5.18701842e-02
#   2.73490490e-01 -9.74261956e-02  7.67263800e-01  1.30311522e-01
#   3.95370787e-03 -1.58794012e-02 -8.02140326e-01 -2.47271322e+00
#   8.73084354e-01  7.06034889e-01 -6.91739434e-02  2.34498092e-01
# ...

# %%
# Out:
# <class 'numpy.ndarray'>

# %%
k
