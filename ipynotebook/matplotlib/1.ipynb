# %%
import matplotlib.pyplot as plt

# %% [markdown]
# matplotlibで画面を分割する方法

# %% [markdown]
# 👇 基本形

# %%
fig, ax = plt.subplots()

# %% [markdown]
# 👇 基本形2

# %%
fig, ax = plt.subplots(2, 2)

# %%
ax
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x121f8da90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121911490>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x121bed750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1219c7a10>]],
#       dtype=object)

# %% [markdown]
# 👆 2 x 2のaxが返ってくる。各axisの位置は👇

# %%
fig, ax = plt.subplots(2, 2)
ax[0,0].text(0.5, 0.5, "0,0")
ax[0,1].text(0.5, 0.5, "0,1")
ax[1,0].text(0.5, 0.5, "1,0")
ax[1,1].text(0.5, 0.5, "1,1")
# Out:
# Text(0.5, 0.5, '1,1')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)
ax1.text(0.5, 0.5, "1")
ax2.text(0.5, 0.5, "2")
# Out:
# Text(0.5, 0.5, '2')

# %% [markdown]
# 👆 明示的に、場所を指定しaxisを取得する場合 `add_subplot(行数, 列数, 場所)`

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
ax1.text(0.5, 0.5, "1")
ax2.text(0.5, 0.5, "2")
ax3.text(0.5, 0.5, "3")
ax4.text(0.5, 0.5, "4")
# Out:
# Text(0.5, 0.5, '4')

# %% [markdown]
# 👆 2x2の例

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,3)
ax3 = fig.add_subplot(1,2,2)
ax1.text(0.5, 0.5, "1")
ax2.text(0.5, 0.5, "2")
ax3.text(0.5, 0.5, "3")
# Out:
# Text(0.5, 0.5, '3')

# %% [markdown]
# 👆 形を変えることも可能らしい
