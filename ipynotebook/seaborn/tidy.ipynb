# %%
import seaborn as sns
import pandas as pd
import numpy as np
from itertools import product

# %%
x = np.linspace(0, 10)
h = np.array([1,2])
y = {(_x, _h): {"y": _x + _h} for _x, _h in product(x, h)}

# %%
df = pd.DataFrame.from_dict(y).T
df.index.names = ["x", "h"]
df = df.reset_index()
df["size"] = np.random.rand(le)

# %%
sns.scatterplot(x="x", y="y", hue="h", data=df)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>
