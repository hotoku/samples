# %%
import numpy as np

# %%
np.random.randn(10, 3, 3)
# Out:
# array([[[ 1.13733497, -0.97701855, -0.30911774],
#         [ 0.88393228,  0.17649302, -1.22933837],
#         [ 1.64896306,  0.21151901, -0.37925893]],
#
#        [[-0.32523994,  0.1971577 ,  1.19075426],
#         [-0.07698881,  1.3659633 ,  0.9809735 ],
#         [ 1.46994487, -0.05047095, -0.05080827]],
#
#        [[ 0.12030131, -0.49214019, -0.77908436],
#         [-0.686912  , -0.90903478, -0.46941253],
#         [ 0.20857285,  0.59637705, -1.95063806]],
#
#        [[ 0.25490522,  1.68857682,  1.39411553],
#         [-1.61481601,  0.1820087 , -0.21349523],
#         [-0.89376983,  0.96461179,  0.29773474]],
#
#        [[-0.19450557,  0.30657956,  0.43263586],
#         [ 0.30433222,  1.54634714,  0.52842114],
#         [ 0.14152518,  0.30219851, -0.75591095]],
#
#        [[-1.35524912,  0.90739575,  0.76744476],
#         [ 0.28774336,  0.15740022, -1.1582498 ],
#         [-1.5440232 , -1.69754231, -0.2362011 ]],
#
#        [[-0.19567124, -0.12430295, -1.83978994],
# ...
