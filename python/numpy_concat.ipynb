# %%
import numpy as np
x = np.zeros(3)
y = np.ones(4)
z = np.zeros(7)
z[3 :] = y
z[: 3] = x

# %%
print(z)
# Out:
# [ 0.  0.  0.  1.  1.  1.  1.]

# %% [markdown]
# 3 :て書くから分かりずらいけど、普通に、3:て「最初の3個」ていうslicingだ。↓と同じ

# %%
list(range(10))[1:]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
x += 2
z[-3:] = x
print(z)
# Out:
# [ 0.  0.  0.  1.  2.  2.  2.]
