# %%
import japanize_matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
titanic = sns.load_dataset("titanic")

# %%
ax = sns.distplot(titanic.fare)

# %%
ax = sns.distplot(titanic.fare)
ax.set_xlim(0, 100)
# Out:
# (0, 100)

# %%
ax = sns.distplot(titanic.fare)
ax.set_title("チケット代の分布")
ax.set_ylabel("割合")
ax.set_xlabel("チケット代")
# Out:
# Text(0.5, 0, 'チケット代')
