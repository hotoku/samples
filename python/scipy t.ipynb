# %%
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt

# %%
t = stats.t(9)
t2 = stats.t(df=9)

# %%
xs = np.linspace(-3,3)
plt.plot(xs, t.pdf(xs))
plt.plot(xs, t2.pdf(xs))
